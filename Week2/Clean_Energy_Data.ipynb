# %%
# Step 1: Load the messy dataset
import pandas as pd

df = pd.read_csv("energy_cleaned.csv")
print("Original Data:")
print(df)

# Step 2: Count missing values
print("\nMissing values:")
print(df.isnull().sum())

# Step 3: Standardize country names and numeric fields
df["Country"] = df["Country"].str.strip().str.title()
df["%Renewable"] = pd.to_numeric(df["%Renewable"].str.replace("%", ""), errors="coerce")

# Step 4: Remove duplicates and unrealistic values
df = df.drop_duplicates()
df = df[df["%Renewable"] <= 100]

# Step 5: View cleaned data
print("\nCleaned Data:")
print(df)
# Out:
# Original Data:
#      Country  %Renewable         Region
# 0      Nepal          89           Asia
# 1      India          45           Asia
# 2      Kenya          50         Africa
# 3     Brazil          95  South America
# 4  Australia          35        Oceania
# 5    Germany          48         Europe
#
# Missing values:
# Country       0
# %Renewable    0
# Region        0
# dtype: int64
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 14
#      10 print(df.isnull().sum())
#      11
#      12 # Step 3: Standardize country names and numeric fields
#      13 df["Country"] = df["Country"].str.strip().str.title()
# ---> 14 df["%Renewable"] = pd.to_numeric(df["%Renewable"].str.replace("%", ""), errors="coerce")
#      15
#      16 # Step 4: Remove duplicates and unrealistic values
#      17 df = df.drop_duplicates()
#
# File ~\Documents\CST184_Examples\Week2\.venv\Lib\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# File ~\Documents\CST184_Examples\Week2\.venv\Lib\site-packages\pandas\core\accessor.py:230, in Accessor.__get__(self, obj, cls)
#     227 if obj is None:
#     228     # we're accessing the attribute of the class, i.e., Dataset.geo
#     229     return self._accessor
# --> 230 return self._accessor(obj)
#
# File ~\Documents\CST184_Examples\Week2\.venv\Lib\site-packages\pandas\core\strings\accessor.py:194, in StringMethods.__init__(self, data)
#     191 def __init__(self, data) -> None:
#     192     from pandas.core.arrays.string_ import StringDtype
# --> 194     self._inferred_dtype = self._validate(data)
#     195     self._is_categorical = isinstance(data.dtype, CategoricalDtype)
#     196     self._is_string = isinstance(data.dtype, StringDtype)
#
# File ~\Documents\CST184_Examples\Week2\.venv\Lib\site-packages\pandas\core\strings\accessor.py:248, in StringMethods._validate(data)
#     245 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     247 if inferred_dtype not in allowed_types:
# --> 248     raise AttributeError(
#     249         f"Can only use .str accessor with string values, not {inferred_dtype}"
#     250     )
#     251 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values, not integer
